# %% [markdown]
# <a href="https://colab.research.google.com/github/parthps/MissingValueAndVisualizationOfData/blob/main/preproccesiing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd 'drive/My Drive/'
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
# '12 to 31 july.pdf'
# '16 to 30 october.pdf'
# '16 to 30 september.pdf'
# '16 to 31 august.pdf'
# '1 to 15 august.pdf'
# '1 to 15 october.pdf'
# '1 to 15 september.pdf'
#  2019-20.pdf
# '21CSE work '/
# '3DCE1 SGP C D.xlsx'
# '7CE1 BDA Practical Exam (Responses).gsheet'
# '7CE2 BDA Practical Exam 2021 (Responses).gsheet'
# '7CE BDA Practical Exam.xls'
# '7CSE1 DSA Practical Exam.gform'
#  7CSE1VivaComponentMarksJigarMPandyaDay2.xlsx
#  7CSE1VivaComponentStudentAttendanceJigarMPandyaDay2.xlsx
# '7CSE2  and 1 Viva Status.gsheet'
# '7CSE2 DSA Practical Exam (File responses)'/
# '7CSE2 DSA Practical Exam (File responses) (1)'/
# '7CSE2 DSA Practical Exam.gform'
# '7CSE2 DSA Practical Exam (Responses).gsheet'
#  7CSE2VivaComponentMarksJigarMPandyaDay1.xlsx
# '7CSE2 Viva component.xlsx'
# 'action taken report.pdf'
# 'Adobe Scan Aug 24, 2021.pdf'
# 'after BOS2 2017-18.pdf'
# 'AI Proposals-converted.pdf'
# 'Anti ragging'/
# 'Assignment Submission (Responses).gsheet'
# ...

# %%
cd 'Colab Notebooks'
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
ls
# Out:
# Iris.csv            MLCS344Second.ipynb  Untitled1.ipynb
# MLCS344First.ipynb  Untitled0.ipynb      winequality-white.csv

# %%
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
X = df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=df['Species']

# %%
X.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# Default test_size is 0.25

# %%
X_train.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 29            4.7           3.2            1.6           0.2
# 98            5.1           2.5            3.0           1.1
# 37            4.9           3.1            1.5           0.1
# 5             5.4           3.9            1.7           0.4
# 81            5.5           2.4            3.7           1.0

# %%
X_test.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 16             5.4           3.9            1.3           0.4
# 78             6.0           2.9            4.5           1.5
# 145            6.7           3.0            5.2           2.3
# 99             5.7           2.8            4.1           1.3
# 126            6.2           2.8            4.8           1.8

# %%
y_train.head()
# Out:
# 29        Iris-setosa
# 98    Iris-versicolor
# 37        Iris-setosa
# 5         Iris-setosa
# 81    Iris-versicolor
# Name: Species, dtype: object

# %%
y_test.head()
# Out:
# 16         Iris-setosa
# 78     Iris-versicolor
# 145     Iris-virginica
# 99     Iris-versicolor
# 126     Iris-virginica
# Name: Species, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
standardized_X = scaler.transform(X_train)
standardized_X_test = scaler.transform(X_test)

# %%
standardized_X
#X_train
# Out:
# array([[ 0.56978378,  0.59946418,  1.2678273 ,  1.72323614],
#        [ 0.69253791,  0.36514594,  0.86473308,  1.45485413],
#        [-0.0439869 , -0.8064453 ,  0.05854464, -0.02124691],
#        [ 1.06080032, -0.10349056,  0.80714819,  1.45485413],
#        [-0.0439869 , -0.8064453 ,  0.7495633 ,  0.91809012],
#        [-1.02601998,  1.06810068, -1.43866247, -1.22896594],
#        [-0.28949517, -0.10349056,  0.17371441,  0.11294409],
#        [ 0.56978378,  0.83378243,  1.03748775,  1.58904513],
#        [-0.16674103, -0.33780881,  0.2312993 ,  0.11294409],
#        [ 0.69253791, -0.57212705,  1.03748775,  1.18647212],
#        [-1.02601998,  1.06810068, -1.2659078 , -0.82639293],
#        [ 0.20152137, -1.97803654,  0.11612953, -0.28962892],
#        [-0.16674103, -0.10349056,  0.2312993 , -0.02124691],
#        [-1.39428239,  0.36514594, -1.43866247, -1.36315694],
#        [ 1.30630859,  0.13082769,  0.92231797,  1.18647212],
# ...

# %%
from sklearn.preprocessing import Normalizer
scaler = Normalizer().fit(X_train)
normalized_X = scaler.transform(X_train)
normalized_X_test = scaler.transform(X_test)

# %%
normalized_X
# Out:
# array([[0.79524064, 0.54144043, 0.27072022, 0.03384003],
#        [0.78258054, 0.38361791, 0.4603415 , 0.16879188],
#        [0.81803119, 0.51752994, 0.25041771, 0.01669451],
#        [0.78417499, 0.5663486 , 0.2468699 , 0.05808704],
#        [0.77242925, 0.33706004, 0.51963422, 0.14044168],
#        [0.75728103, 0.3542121 , 0.52521104, 0.15878473],
#        [0.73446047, 0.37367287, 0.5411814 , 0.16750853],
#        [0.71529453, 0.31790868, 0.59607878, 0.17882363],
#        [0.77011854, 0.35349703, 0.50499576, 0.16412362],
#        [0.81803119, 0.51752994, 0.25041771, 0.01669451],
#        [0.73239618, 0.38547167, 0.53966034, 0.15418867],
#        [0.76785726, 0.34902603, 0.51190484, 0.16287881],
#        [0.79837025, 0.55735281, 0.22595384, 0.03012718],
#        [0.75676497, 0.35228714, 0.53495455, 0.13047672],
#        [0.71718148, 0.31640359, 0.58007326, 0.22148252],
#        [0.74714194, 0.33960997, 0.54337595, 0.17659719],
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
bestfeatures = SelectKBest(score_func=chi2, k=4)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(4,'Score'))  #print 10 best features
# Out:
#            Specs       Score
# 2  PetalLengthCm  116.169847
# 3   PetalWidthCm   67.244828
# 0  SepalLengthCm   10.817821
# 1   SepalWidthCm    3.594499

# %%
dfscores
# Out:
#             0
# 0   10.817821
# 1    3.594499
# 2  116.169847
# 3   67.244828

# %%
dfcolumns
# Out:
#                0
# 0  SepalLengthCm
# 1   SepalWidthCm
# 2  PetalLengthCm
# 3   PetalWidthCm

# %%
featureScores
# Out:
#            Specs       Score
# 0  SepalLengthCm   10.817821
# 1   SepalWidthCm    3.594499
# 2  PetalLengthCm  116.169847
# 3   PetalWidthCm   67.244828

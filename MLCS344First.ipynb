# %% [markdown]
# <a href="https://colab.research.google.com/github/parthps/parthps/blob/main/MLCS344First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
cd 'My Drive'
# Out:
# /gdrive/My Drive

# %%
ls
# Out:
# '12 to 31 july.pdf'
# '16 to 30 october.pdf'
# '16 to 30 september.pdf'
# '16 to 31 august.pdf'
# '1 to 15 august.pdf'
# '1 to 15 october.pdf'
# '1 to 15 september.pdf'
#  2019-20.pdf
# '21CSE work '/
# '3DCE1 SGP C D.xlsx'
# '6CSE ML UNIT TEST 1.gform'
# '7CE1 BDA Practical Exam (Responses).gsheet'
# '7CE2 BDA Practical Exam 2021 (Responses).gsheet'
# '7CE BDA Practical Exam.xls'
# '7CSE1 DSA Practical Exam.gform'
#  7CSE1VivaComponentMarksJigarMPandyaDay2.xlsx
#  7CSE1VivaComponentStudentAttendanceJigarMPandyaDay2.xlsx
# '7CSE2  and 1 Viva Status.gsheet'
# '7CSE2 DSA Practical Exam (File responses)'/
# '7CSE2 DSA Practical Exam (File responses) (1)'/
# '7CSE2 DSA Practical Exam.gform'
# '7CSE2 DSA Practical Exam (Responses).gsheet'
#  7CSE2VivaComponentMarksJigarMPandyaDay1.xlsx
# '7CSE2 Viva component.xlsx'
# 'action taken report.pdf'
# 'Adobe Scan Aug 24, 2021.pdf'
# 'after BOS2 2017-18.pdf'
# 'AI Proposals-converted.pdf'
# 'Anti ragging'/
# ...

# %%
cd 'Colab Notebooks'
# Out:
# /gdrive/My Drive/Colab Notebooks

# %%
ls
# Out:
#  breast-cancer.data            MLCS344Second.ipynb       Untitled
# 'Copy of MLCS344Sixth.ipynb'  'MLCS344Third (1).ipynb'   Untitled0.ipynb
# 'external exam.ipynb'          MLCS344Third.ipynb        Untitled1.ipynb
#  Iris.csv                      MLCSS344seventh.ipynb     Untitled2.ipynb
#  MLCS344Fifth.ipynb            MLNinthPractical.ipynb    winequality-white.csv
#  MLCS344First.ipynb            ML_Prac7FINAL.ipynb

# %%
df = pd.read_csv('winequality-white.csv', sep=';')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
new_df=df.head(10)
new_df
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %%
new_df =df.dropna()
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
new_df.replace(to_replace="-", value=np.NaN, inplace=True)
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
mean = df.mean()
mode = df.mode()
median = df.median()
#mean
mean_df= new_df.fillna(value="mean", inplace=False)
mode_df= new_df.fillna(value="mode", inplace=False)
median_df= new_df.fillna(value="median", inplace=False)

# %%
mean_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
mode_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
median_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
new_df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import seaborn as sn
corrMatrix = new_df.corr()
sn.heatmap(corrMatrix, annot=True)

# %%
plt.hist(new_df['fixed acidity'], color='#0504aa', alpha=0.7, bins=5)
plt.xticks(np.arange(1,20, step=5))
plt.title('Total Score Histogram',fontsize=15)
plt.show()

# %%
new_df['quality'].dtype
# Out:
# dtype('int64')

# %%
idf = pd.read_csv('Iris.csv')

# %%
idf.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(idf['SepalLengthCm'], idf['SepalWidthCm'], marker='o')
plt.show()

# %%
sn.boxplot(x='PetalLengthCm', y='Species', data=idf)

# %%
plt.hist(idf['SepalWidthCm'], alpha=0.7, bins=5)
plt.show()

# %%
plt.hist(idf['SepalWidthCm'], alpha=0.7, bins=10)
plt.show()
